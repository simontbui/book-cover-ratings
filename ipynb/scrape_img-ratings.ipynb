# %%
import requests
from proxycrawl import CrawlingAPI
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import quote_plus
import json
import pprint
import ast
import pandas as pd

# %%
token = "pIiVoNtQfnMuNI80pGbkKw"

# %%
book_info = {"img": [], "rating": [], "num_rating": []}

# %%
for i in range(1, 401):
    url = quote_plus(f"https://www.amazon.com/s?i=digital-text&rh=n%3A158571011&fs=true&page={i}")
    handler = urlopen(f"https://api.proxycrawl.com/?token={token}&scraper=amazon-serp&url={url}")
    serp = json.loads(handler.read().decode("utf-8"))
    prod_info = serp['body']['products']
    
    for ebook in prod_info:
        book_info["img"].append(ebook["image"])
        book_info["rating"].append(ebook["customerReview"])
        book_info["num_rating"].append(ebook["customerReviewCount"])

# %%
pd.DataFrame(book_info)
# Out:
#                                                     img              rating  \
# 0     https://m.media-amazon.com/images/I/91tjikkfB6...  4.7 out of 5 stars
# 1     https://m.media-amazon.com/images/I/91JkRgWPWx...  4.4 out of 5 stars
# 2     https://m.media-amazon.com/images/I/71EfdZLKe9...  4.8 out of 5 stars
# 3     https://m.media-amazon.com/images/I/91P4oiK4SC...  4.8 out of 5 stars
# 4     https://m.media-amazon.com/images/I/81XNHNN0Jh...  4.5 out of 5 stars
# ...                                                 ...                 ...
# 6379  https://m.media-amazon.com/images/I/817s-jg3HV...  4.4 out of 5 stars
# 6380  https://m.media-amazon.com/images/I/9149YZb7lO...  4.8 out of 5 stars
# 6381  https://m.media-amazon.com/images/I/91sN8qa-cz...  4.3 out of 5 stars
# 6382  https://m.media-amazon.com/images/I/810Gx5CMdO...  4.4 out of 5 stars
# 6383  https://m.media-amazon.com/images/I/81m2a52d78...  4.4 out of 5 stars
#
#       num_rating
# 0          34203
# 1           5549
# 2          11582
# 3          13780
# 4           3265
# ...          ...
# 6379         299
# 6380          89
# 6381         328
# 6382          27
# 6383          44
#
# [6384 rows x 3 columns]

# %%
df = pd.DataFrame(book_info)
df = df.drop_duplicates()
df
# Out:
#                                                     img              rating  \
# 0     https://m.media-amazon.com/images/I/91tjikkfB6...  4.7 out of 5 stars
# 1     https://m.media-amazon.com/images/I/91JkRgWPWx...  4.4 out of 5 stars
# 2     https://m.media-amazon.com/images/I/71EfdZLKe9...  4.8 out of 5 stars
# 3     https://m.media-amazon.com/images/I/91P4oiK4SC...  4.8 out of 5 stars
# 4     https://m.media-amazon.com/images/I/81XNHNN0Jh...  4.5 out of 5 stars
# ...                                                 ...                 ...
# 6379  https://m.media-amazon.com/images/I/817s-jg3HV...  4.4 out of 5 stars
# 6380  https://m.media-amazon.com/images/I/9149YZb7lO...  4.8 out of 5 stars
# 6381  https://m.media-amazon.com/images/I/91sN8qa-cz...  4.3 out of 5 stars
# 6382  https://m.media-amazon.com/images/I/810Gx5CMdO...  4.4 out of 5 stars
# 6383  https://m.media-amazon.com/images/I/81m2a52d78...  4.4 out of 5 stars
#
#       num_rating
# 0          34203
# 1           5549
# 2          11582
# 3          13780
# 4           3265
# ...          ...
# 6379         299
# 6380          89
# 6381         328
# 6382          27
# 6383          44
#
# [6384 rows x 3 columns]

# %%
df.to_csv("ebook_info.csv", index=False)
